# %%
# ── Importações ────────────────────────────────────────────────────────────────
# Detecção do root folder
# Importações
import sys
import os
import pathlib
import numpy as np
import pandas as pd
notebook_path = pathlib.Path().absolute()
root_folder = notebook_path.parent

# Adicionar src ao path
SRC_DIR = root_folder
sys.path.append(str(SRC_DIR))
from pathlib import Path
from seu_pacote import process_vazao, process_cota, process_precipitacao, main

# ── 1. Processar um único arquivo ──────────────────────────────────────────────
path_vazao = Path("data/raw_source_ana/vazao/12345600.csv")

df_vazao = process_vazao(path_vazao)
df_vazao.head()
